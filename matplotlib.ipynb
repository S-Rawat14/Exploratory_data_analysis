# %% [markdown]
# <a href="https://colab.research.google.com/github/S-Rawat14/Exploratory_data_analysis/blob/main/matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
x = np.linspace(0,10,200)

# %%
x
# Out:
# array([ 0.        ,  0.05025126,  0.10050251,  0.15075377,  0.20100503,
#         0.25125628,  0.30150754,  0.35175879,  0.40201005,  0.45226131,
#         0.50251256,  0.55276382,  0.60301508,  0.65326633,  0.70351759,
#         0.75376884,  0.8040201 ,  0.85427136,  0.90452261,  0.95477387,
#         1.00502513,  1.05527638,  1.10552764,  1.15577889,  1.20603015,
#         1.25628141,  1.30653266,  1.35678392,  1.40703518,  1.45728643,
#         1.50753769,  1.55778894,  1.6080402 ,  1.65829146,  1.70854271,
#         1.75879397,  1.80904523,  1.85929648,  1.90954774,  1.95979899,
#         2.01005025,  2.06030151,  2.11055276,  2.16080402,  2.21105528,
#         2.26130653,  2.31155779,  2.36180905,  2.4120603 ,  2.46231156,
#         2.51256281,  2.56281407,  2.61306533,  2.66331658,  2.71356784,
#         2.7638191 ,  2.81407035,  2.86432161,  2.91457286,  2.96482412,
#         3.01507538,  3.06532663,  3.11557789,  3.16582915,  3.2160804 ,
# ...

# %%
y=  np.sin(x)

# %%
y
# Out:
# array([ 0.        ,  0.05023011,  0.10033341,  0.15018339,  0.19965422,
#         0.24862099,  0.29696008,  0.34454944,  0.39126893,  0.43700061,
#         0.481629  ,  0.52504145,  0.56712835,  0.60778345,  0.6469041 ,
#         0.68439153,  0.72015112,  0.75409257,  0.78613019,  0.8161831 ,
#         0.84417544,  0.87003651,  0.89370105,  0.91510929,  0.9342072 ,
#         0.95094655,  0.96528509,  0.97718662,  0.98662108,  0.99356467,
#         0.99799984,  0.99991541,  0.99930653,  0.99617474,  0.99052796,
#         0.98238043,  0.97175273,  0.95867168,  0.94317032,  0.92528777,
#         0.90506919,  0.88256563,  0.85783388,  0.8309364 ,  0.80194109,
#         0.77092115,  0.7379549 ,  0.70312557,  0.66652108,  0.62823386,
#         0.58836056,  0.54700186,  0.50426216,  0.46024937,  0.41507461,
#         0.36885193,  0.32169803,  0.27373195,  0.22507478,  0.17584939,
#         0.12618003,  0.07619211,  0.02601183, -0.02423412, -0.07441889,
# ...

# %%
plt.plot(x,y)

# %%
plt.plot(x,y)
plt.xlabel("this is my x data")
plt.ylabel("this is myn y data")
plt.title("this is my title ")
# Out:
# Text(0.5, 1.0, 'this is my title ')

# %%
x= np.random.rand(50)
y= np.random.rand(50)
plt.scatter(x,y)

# %%
x
# Out:
# array([0.66275731, 0.58883348, 0.25191671, 0.66871688, 0.69774046,
#        0.12348947, 0.08082936, 0.01763915, 0.0390092 , 0.55474561,
#        0.42029048, 0.73056087, 0.57130251, 0.81787361, 0.35626216,
#        0.09735131, 0.34324929, 0.41069409, 0.85676059, 0.39698209,
#        0.42857834, 0.41462267, 0.19165432, 0.64634558, 0.78568411,
#        0.06638015, 0.34458397, 0.30667455, 0.29022809, 0.04128804,
#        0.29818914, 0.48809997, 0.90582341, 0.43352536, 0.88185219,
#        0.22177204, 0.69313999, 0.05731173, 0.30594875, 0.71310426,
#        0.24053685, 0.00968291, 0.25912183, 0.1520452 , 0.13971268,
#        0.44303692, 0.47958219, 0.09576496, 0.14763802, 0.2607822 ])

# %%
y
# Out:
# array([0.09263725, 0.64135008, 0.80121399, 0.35181079, 0.55948276,
#        0.64186915, 0.36488356, 0.72527179, 0.69727172, 0.43445351,
#        0.68864154, 0.6476047 , 0.43456699, 0.54350896, 0.72347082,
#        0.18295939, 0.1228644 , 0.09801921, 0.75589418, 0.30125407,
#        0.73985206, 0.19124596, 0.0084033 , 0.76533447, 0.00952772,
#        0.14797282, 0.26837533, 0.77735262, 0.61468527, 0.66366163,
#        0.27408615, 0.24475552, 0.056585  , 0.22537786, 0.63227991,
#        0.86500749, 0.24973969, 0.98344173, 0.83723944, 0.38700121,
#        0.43448291, 0.561918  , 0.62639286, 0.0013956 , 0.91675328,
#        0.35284454, 0.3923765 , 0.05124611, 0.40051357, 0.8064252 ])

# %%
colours =np.random.rand(50)

# %%
plt.scatter(x,y,c= colours)

# %%
x= ['a','b','c','d','e']

# %%
y= np.random.rand(5)

# %%
plt.bar(x,y)
# Out:
# <BarContainer object of 5 artists>

# %%
plt.plot(x,y,'--g')
plt.xlabel("this is my x data")
plt.ylabel("this is myn y data")
plt.title("this is my title ")
plt.grid()
plt.show()

# %%
x= np.random.rand(50)
y= np.random.rand(50)
colours =np.random.rand(50)
plt.title("data")
plt.scatter(x,y , c ='b', alpha =.3)

# %%
x= [4,5,6,7,8,9]

# %%
y= [6,7,8,9,10,11]

# %%
plt.plot(x,y)
plt.show()

# %%
plt.scatter(x,y)

# %%
plt.hist(x,y)
# Out:
# (array([1., 1., 1., 1., 0.]),
#  array([ 6.,  7.,  8.,  9., 10., 11.]),
#  <BarContainer object of 5 artists>)

# %%
x = np.random.rand(50)
y = np.random.rand(50)
z = np.random.rand(50)
fig= plt.figure()
ax = fig.add_subplot(projection ='3d')
ax.scatter(x,y,z)

# %%
x = np.random.rand(50)
y = np.random.rand(50)
z = np.random.rand(50)
fig= plt.figure()
ax = fig.add_subplot(projection ='3d')
ax.plot(x,y,z)
