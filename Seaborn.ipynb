# %% [markdown]
# <a href="https://colab.research.google.com/github/S-Rawat14/Exploratory_data_analysis/blob/main/Seaborn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import seaborn as sns

# %%
iris = sns.load_dataset('iris')
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
sns.scatterplot(x = iris.sepal_length, y = iris.sepal_width)
# Out:
# <Axes: xlabel='sepal_length', ylabel='sepal_width'>

# %%
sns.scatterplot(x = iris.sepal_length, y = iris.petal_width)
# Out:
# <Axes: xlabel='sepal_length', ylabel='petal_width'>

# %%
sns.displot(x= iris['sepal_length'])

# %%
# this displot shows that the maximum count is of from 5.5-6.5 of sepal length

# %%
t=sns.load_dataset('tips')

# %%
t
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
t.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.scatterplot(x=t.total_bill,y=t.tip)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
t["smoker"].value_counts()
# Out:
# smoker
# No     151
# Yes     93
# Name: count, dtype: int64

# %%
sns.displot(x=t['smoker'])

# %%
sns.relplot(x= t.total_bill,y= t.tip,data = t, hue = 'smoker')

# %% [markdown]
# # **# if asked if the person who paid the highest tip was a smoker or non smoker , the hue fxn explains it using colour that it was "smoker"!
# #earlier it was mentioned
# #smoker
# No     151
# Yes     93
# **

# %%
sns.relplot(x= t.total_bill,y= t.tip,data = t, hue = 'size')

# %% [markdown]
# # **this graph explain that person who paid most bill and tip came with a group of 3 people**
#
#
# sns.relplot(x= t.total_bill,y= t.tip,data = t, style = 'size')

# %%
the size function discriminates the data on the basis of the people




sns.relplot(x= t.total_bill,y= t.tip,data = t, hue = 'smoker', style ='size')

# %% [markdown]
# # **this graph explains that the person who spend the most money and gave most tips was a smoker **

# %%
sns.catplot( x= 'day',y= 'total_bill', data = t)

# %% [markdown]
# # **the graph explains that most of the people vist resturants on thursday, sat, sun**

# %%
t.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.catplot( x= 'smoker',y= 'tip', data = t)

# %% [markdown]
# # ** this graph explains then most btip was given by a smoker**

# %%
sns.jointplot(y= 'tip',x= 'total_bill', data = t)

# %% [markdown]
# #** this is a joint plot of scatter plot and data distribution using histogram , ex- we can see that  a arange of 2-4 people have given the most amount of bill (on an average)**

# %%
sns.pairplot(t)

# %% [markdown]
# #** this graph explain all the attributes relationship with each other **

# %%
sns.pairplot(iris)

# %% [markdown]
# #** all V/S all**
